# %%
# %%capture
# !pip install -q unsloth
# !pip install -q transformers==4.56.2 trl==0.22.2
# !pip install -q jiwer einops addict easydict

# %%
from huggingface_hub import snapshot_download
snapshot_download("unsloth/DeepSeek-OCR", local_dir = "deepseek_ocr")
# Out:
# Fetching 21 files:   0%|          | 0/21 [00:00<?, ?it/s]
# README.md: 0.00B [00:00, ?B/s]
# README-checkpoint.md: 0.00B [00:00, ?B/s]
# LICENSE: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# assets/show1.jpg:   0%|          | 0.00/117k [00:00<?, ?B/s]
# assets/show3.jpg:   0%|          | 0.00/247k [00:00<?, ?B/s]
# assets/show4.jpg:   0%|          | 0.00/269k [00:00<?, ?B/s]
# assets/show2.jpg:   0%|          | 0.00/216k [00:00<?, ?B/s]
# configuration_deepseek_v2.py: 0.00B [00:00, ?B/s]
# conversation.py: 0.00B [00:00, ?B/s]
# assets/fig1.png:   0%|          | 0.00/396k [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# deepencoder.py: 0.00B [00:00, ?B/s]
# model-00001-of-000001.safetensors:   0%|          | 0.00/6.67G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# modeling_deepseekocr.py: 0.00B [00:00, ?B/s]
# modeling_deepseekv2.py: 0.00B [00:00, ?B/s]
# processor_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/801 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# '/kaggle/working/deepseek_ocr'

# %%
from unsloth import FastVisionModel # FastLanguageModel for LLMs
import torch
from transformers import AutoModel
import os
os.environ["UNSLOTH_WARN_UNINITIALIZED"] = '0'
# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Qwen3-VL-8B-Instruct-bnb-4bit", # Qwen 3 vision support
    "unsloth/Qwen3-VL-8B-Thinking-bnb-4bit",
    "unsloth/Qwen3-VL-32B-Instruct-bnb-4bit",
    "unsloth/Qwen3-VL-32B-Thinking-bnb-4bit",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastVisionModel.from_pretrained(
    "./deepseek_ocr",
    load_in_4bit = False, # Use 4bit to reduce memory use. False for 16bit LoRA.
    auto_model = AutoModel,
    trust_remote_code=True,
    unsloth_force_compile=True,
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for long context
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-12-28 13:18:47.610679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766927928.006677     156 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766927928.188304     156 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766927929.590367     156 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766927929.590397     156 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766927929.590400     156 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766927929.590403     156 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2025.12.9: Fast Deepseekocr patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at ./deepseek_ocr and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Load dataset

# %%
import os, json
from datasets import Dataset

def load_hwdb_split(
    dataset_dir,
    split="train_data",
):
    split_dir = os.path.join(dataset_dir, split)
    if not os.path.isdir(split_dir):
        raise FileNotFoundError(f"Không tìm thấy thư mục {split_dir}")

    samples = []
    subfolders = sorted(os.listdir(split_dir))

    for sub in subfolders:
        sub_path = os.path.join(split_dir, sub)
        label_path = os.path.join(sub_path, "label.json")

        if not os.path.isdir(sub_path) or not os.path.exists(label_path):
            continue

        with open(label_path, "r", encoding="utf-8-sig") as f:
            labels = json.load(f)

        for img_name, text in labels.items():
            img_path = os.path.join(sub_path, img_name)
            if not os.path.exists(img_path):
                continue

            samples.append({
                "image_path": img_path,
                "text": text.strip()
            })

    return Dataset.from_list(samples)

# %%
BASE_DIR = "/kaggle/input/dataset-vn-handwritten-ocr/Vietnamese_Handwritten_OCR"

LINE_DIR = os.path.join(
    BASE_DIR,
    "UIT_HWDB_line",
    "UIT_HWDB_line"
)

PARA_DIR = os.path.join(
    BASE_DIR,
    "UIT_HWDB_paragraph",
    "UIT_HWDB_paragraph"
)

ds_line = load_hwdb_split(
    dataset_dir=LINE_DIR,
    split="train_data"
)

ds_para = load_hwdb_split(
    dataset_dir=PARA_DIR,
    split="train_data"
)

from datasets import concatenate_datasets

dataset = concatenate_datasets([ds_line, ds_para])

print(dataset)
print("Total samples:", len(dataset))
# Out:
# Dataset({
#     features: ['image_path', 'text'],
#     num_rows: 8141
# })
# Total samples: 8141

# %% [markdown]
# Cài đặt các tham số cho model

# %%
model = FastVisionModel.get_peft_model(
    model,
    target_modules = [
        "q_proj",
        "v_proj",
        "o_proj",
    ],

    r = 8,       
    lora_alpha = 16, 
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False, 
    loftq_config = None,
    # target_modules = "all-linear", # Optional now! Can specify a list if needed
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %%
from PIL import Image

instruction = "\nFree OCR."

def convert_to_conversation(sample):
    image = Image.open(sample["image_path"]).convert("RGB")
    return {
        "messages": [
            {
                "role": "<|User|>",
                "content": instruction,
                "images": [image],
            },
            {
                "role": "<|Assistant|>",
                "content": sample["text"],
            }
        ]
    }

# %%
converted_dataset = [convert_to_conversation(sample) for sample in dataset]

# %% [markdown]
# Sắp xếp data

# %%
import torch
import math
from dataclasses import dataclass
from typing import Dict, List, Any, Tuple
from PIL import Image, ImageOps
from torch.nn.utils.rnn import pad_sequence
import io

from deepseek_ocr.modeling_deepseekocr import (
    format_messages,
    text_encode,
    BasicImageTransform,
    dynamic_preprocess,
)

@dataclass
class DeepSeekOCRDataCollator:
    """
    Args:
        tokenizer: Tokenizer
        model: Model
        image_size: Size for image patches (default: 640)
        base_size: Size for global view (default: 1024)
        crop_mode: Whether to use dynamic cropping for large images
        train_on_responses_only: If True, only train on assistant responses (mask user prompts)
    """
    tokenizer: Any
    model: Any
    image_size: int = 640
    base_size: int = 1024
    crop_mode: bool = True
    image_token_id: int = 128815
    train_on_responses_only: bool = True

    def __init__(
        self,
        tokenizer,
        model,
        image_size: int = 640,
        base_size: int = 1024,
        crop_mode: bool = True,
        train_on_responses_only: bool = True,
    ):
        self.tokenizer = tokenizer
        self.model = model
        self.image_size = image_size
        self.base_size = base_size
        self.crop_mode = crop_mode
        self.image_token_id = 128815
        self.dtype = model.dtype  # Get dtype from model
        self.train_on_responses_only = train_on_responses_only

        self.image_transform = BasicImageTransform(
            mean=(0.5, 0.5, 0.5),
            std=(0.5, 0.5, 0.5),
            normalize=True
        )
        self.patch_size = 16
        self.downsample_ratio = 4

        # Get BOS token ID from tokenizer
        if hasattr(tokenizer, 'bos_token_id') and tokenizer.bos_token_id is not None:
            self.bos_id = tokenizer.bos_token_id
        else:
            self.bos_id = 0
            print(f"Warning: tokenizer has no bos_token_id, using default: {self.bos_id}")

    def deserialize_image(self, image_data) -> Image.Image:
        """Convert image data (bytes dict or PIL Image) to PIL Image in RGB mode"""
        if isinstance(image_data, Image.Image):
            return image_data.convert("RGB")
        elif isinstance(image_data, dict) and 'bytes' in image_data:
            image_bytes = image_data['bytes']
            image = Image.open(io.BytesIO(image_bytes))
            return image.convert("RGB")
        else:
            raise ValueError(f"Unsupported image format: {type(image_data)}")

    def calculate_image_token_count(self, image: Image.Image, crop_ratio: Tuple[int, int]) -> int:
        """Calculate the number of tokens this image will generate"""
        num_queries = math.ceil((self.image_size // self.patch_size) / self.downsample_ratio)
        num_queries_base = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)

        width_crop_num, height_crop_num = crop_ratio

        if self.crop_mode:
            img_tokens = num_queries_base * num_queries_base + 1
            if width_crop_num > 1 or height_crop_num > 1:
                img_tokens += (num_queries * width_crop_num + 1) * (num_queries * height_crop_num)
        else:
            img_tokens = num_queries * num_queries + 1

        return img_tokens

    def process_image(self, image: Image.Image) -> Tuple[List, List, List, List, Tuple[int, int]]:
        """
        Process a single image based on crop_mode and size thresholds

        Returns:
            Tuple of (images_list, images_crop_list, images_spatial_crop, tokenized_image, crop_ratio)
        """
        images_list = []
        images_crop_list = []
        images_spatial_crop = []

        if self.crop_mode:
            # Determine crop ratio based on image size
            if image.size[0] <= 640 and image.size[1] <= 640:
                crop_ratio = (1, 1)
                images_crop_raw = []
            else:
                images_crop_raw, crop_ratio = dynamic_preprocess(
                    image, min_num=2, max_num=9,
                    image_size=self.image_size, use_thumbnail=False
                )

            # Process global view with padding
            global_view = ImageOps.pad(
                image, (self.base_size, self.base_size),
                color=tuple(int(x * 255) for x in self.image_transform.mean)
            )
            images_list.append(self.image_transform(global_view).to(self.dtype))

            width_crop_num, height_crop_num = crop_ratio
            images_spatial_crop.append([width_crop_num, height_crop_num])

            # Process local views (crops) if applicable
            if width_crop_num > 1 or height_crop_num > 1:
                for crop_img in images_crop_raw:
                    images_crop_list.append(
                        self.image_transform(crop_img).to(self.dtype)
                    )

            # Calculate image tokens
            num_queries = math.ceil((self.image_size // self.patch_size) / self.downsample_ratio)
            num_queries_base = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)

            tokenized_image = ([self.image_token_id] * num_queries_base + [self.image_token_id]) * num_queries_base
            tokenized_image += [self.image_token_id]

            if width_crop_num > 1 or height_crop_num > 1:
                tokenized_image += ([self.image_token_id] * (num_queries * width_crop_num) + [self.image_token_id]) * (
                    num_queries * height_crop_num)

        else:  # crop_mode = False
            crop_ratio = (1, 1)
            images_spatial_crop.append([1, 1])

            # For smaller base sizes, resize; for larger, pad
            if self.base_size <= 640:
                resized_image = image.resize((self.base_size, self.base_size), Image.LANCZOS)
                images_list.append(self.image_transform(resized_image).to(self.dtype))
            else:
                global_view = ImageOps.pad(
                    image, (self.base_size, self.base_size),
                    color=tuple(int(x * 255) for x in self.image_transform.mean)
                )
                images_list.append(self.image_transform(global_view).to(self.dtype))

            num_queries = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)
            tokenized_image = ([self.image_token_id] * num_queries + [self.image_token_id]) * num_queries
            tokenized_image += [self.image_token_id]

        return images_list, images_crop_list, images_spatial_crop, tokenized_image, crop_ratio

    def process_single_sample(self, messages: List[Dict]) -> Dict[str, Any]:
            """
            Process a single conversation into model inputs.
            """

            # --- 1. Setup ---
            images = []
            for message in messages:
                if "images" in message and message["images"]:
                    for img_data in message["images"]:
                        if img_data is not None:
                            pil_image = self.deserialize_image(img_data)
                            images.append(pil_image)

            if not images:
                raise ValueError("No images found in sample. Please ensure all samples contain images.")

            tokenized_str = []
            images_seq_mask = []
            images_list, images_crop_list, images_spatial_crop = [], [], []

            prompt_token_count = -1 # Index to start training
            assistant_started = False
            image_idx = 0

            # Add BOS token at the very beginning
            tokenized_str.append(self.bos_id)
            images_seq_mask.append(False)

            for message in messages:
                role = message["role"]
                content = message["content"]

                # Check if this is the assistant's turn
                if role == "<|Assistant|>":
                    if not assistant_started:
                        # This is the split point. All tokens added *so far*
                        # are part of the prompt.
                        prompt_token_count = len(tokenized_str)
                        assistant_started = True

                    # Append the EOS token string to the *end* of assistant content
                    content = f"{content.strip()} {self.tokenizer.eos_token}"

                # Split this message's content by the image token
                text_splits = content.split('')

                for i, text_sep in enumerate(text_splits):
                    # Tokenize the text part
                    tokenized_sep = text_encode(self.tokenizer, text_sep, bos=False, eos=False)
                    tokenized_str.extend(tokenized_sep)
                    images_seq_mask.extend([False] * len(tokenized_sep))

                    # If this text is followed by an  tag
                    if i < len(text_splits) - 1:
                        if image_idx >= len(images):
                            raise ValueError(
                                f"Data mismatch: Found '' token but no corresponding image."
                            )

                        # Process the image
                        image = images[image_idx]
                        img_list, crop_list, spatial_crop, tok_img, _ = self.process_image(image)

                        images_list.extend(img_list)
                        images_crop_list.extend(crop_list)
                        images_spatial_crop.extend(spatial_crop)

                        # Add image placeholder tokens
                        tokenized_str.extend(tok_img)
                        images_seq_mask.extend([True] * len(tok_img))

                        image_idx += 1 # Move to the next image

            # --- 3. Validation and Final Prep ---
            if image_idx != len(images):
                raise ValueError(
                    f"Data mismatch: Found {len(images)} images but only {image_idx} '' tokens were used."
                )

            # If we never found an assistant message, we're in a weird state
            # (e.g., user-only prompt). We mask everything.
            if not assistant_started:
                print("Warning: No assistant message found in sample. Masking all tokens.")
                prompt_token_count = len(tokenized_str)

            # Prepare image tensors
            images_ori = torch.stack(images_list, dim=0)
            images_spatial_crop_tensor = torch.tensor(images_spatial_crop, dtype=torch.long)

            if images_crop_list:
                images_crop = torch.stack(images_crop_list, dim=0)
            else:
                images_crop = torch.zeros((1, 3, self.base_size, self.base_size), dtype=self.dtype)

            return {
                "input_ids": torch.tensor(tokenized_str, dtype=torch.long),
                "images_seq_mask": torch.tensor(images_seq_mask, dtype=torch.bool),
                "images_ori": images_ori,
                "images_crop": images_crop,
                "images_spatial_crop": images_spatial_crop_tensor,
                "prompt_token_count": prompt_token_count, # This is now accurate
            }

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, torch.Tensor]:
        """Collate batch of samples"""
        batch_data = []

        # Process each sample
        for feature in features:
            try:
                processed = self.process_single_sample(feature['messages'])
                batch_data.append(processed)
            except Exception as e:
                print(f"Error processing sample: {e}")
                continue

        if not batch_data:
            raise ValueError("No valid samples in batch")

        # Extract lists
        input_ids_list = [item['input_ids'] for item in batch_data]
        images_seq_mask_list = [item['images_seq_mask'] for item in batch_data]
        prompt_token_counts = [item['prompt_token_count'] for item in batch_data]

        # Pad sequences
        input_ids = pad_sequence(input_ids_list, batch_first=True, padding_value=self.tokenizer.pad_token_id)
        images_seq_mask = pad_sequence(images_seq_mask_list, batch_first=True, padding_value=False)

        # Create labels
        labels = input_ids.clone()

        # Mask padding tokens
        labels[labels == self.tokenizer.pad_token_id] = -100

        # Mask image tokens (model shouldn't predict these)
        labels[images_seq_mask] = -100

        # Mask user prompt tokens when train_on_responses_only=True (only train on assistant responses)
        if self.train_on_responses_only:
            for idx, prompt_count in enumerate(prompt_token_counts):
                if prompt_count > 0:
                    labels[idx, :prompt_count] = -100

        # Create attention mask
        attention_mask = (input_ids != self.tokenizer.pad_token_id).long()

        # Prepare images batch (list of tuples)
        images_batch = []
        for item in batch_data:
            images_batch.append((item['images_crop'], item['images_ori']))

        # Stack spatial crop info
        images_spatial_crop = torch.cat([item['images_spatial_crop'] for item in batch_data], dim=0)

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels,
            "images": images_batch,
            "images_seq_mask": images_seq_mask,
            "images_spatial_crop": images_spatial_crop,
        }

# %%
from transformers import Trainer, TrainingArguments
from unsloth import is_bf16_supported
FastVisionModel.for_training(model) # Enable for training!
data_collator = DeepSeekOCRDataCollator(
    tokenizer=tokenizer,
    model = model,
    image_size=640,
    base_size=640,
    crop_mode=True,
    train_on_responses_only=True,
)
trainer = Trainer(
    model = model,
    tokenizer = tokenizer,
    data_collator = data_collator,
    train_dataset = converted_dataset,
    args = TrainingArguments(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        warmup_steps = 5,
        max_steps = 600,
        # num_train_epochs = 1,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.001,
        lr_scheduler_type = "linear",
        seed = 3407,
        fp16 = True,  # Use fp16 if bf16 is not supported
        # bf16 = is_bf16_supported(),  # Use bf16 if supported
        output_dir = "outputs",
        report_to = "none",     # For Weights and Biases
        dataloader_num_workers=2,
        # You MUST put the below items for vision finetuning:
        remove_unused_columns = False,

        # CHECKPOINT AN TOÀN
        save_strategy = "steps",
        save_steps = 500,              # mỗi 500 step lưu 1 checkpoint
        save_total_limit = 3,          # chỉ giữ tối đa 3 cái
    ),
)
# Out:
# /tmp/ipykernel_156/1906771972.py:12: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer._unsloth___init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %% [markdown]
# Quá trình Fine-tuning

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 8,141 | Num Epochs = 2 | Total steps = 600
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 8 x 1) = 16
#  "-____-"     Trainable parameters = 737,280 of 3,336,843,520 (0.02% trained)
# Unsloth: Not an error, but DeepseekOCRForCausalLM does not accept `num_items_in_batch`.
# Using gradient accumulation will be very slightly less accurate.
# Read more on gradient accumulation issues here: https://unsloth.ai/blog/gradient
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# Unsloth: Will smartly offload gradients to save VRAM!
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 2:49:58, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.630900</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.423400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.535200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.255500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.479700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.310600</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.397200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.019500</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.285400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.301200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.115900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.457500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.939800</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.912600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.085500</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.930800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.834000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.163700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.140000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.956400</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.955500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.989300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.861400</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.188500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.774500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.935400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.831100</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.820400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.808900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.959100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.952800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.832700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.220000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.810400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.976400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.821600</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.920500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.004700</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.815400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.777200</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.678700</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.978600</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.766100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.863900</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.994400</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.912300</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.655500</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.793000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.769600</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.765600</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.863600</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.962800</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.906900</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.133300</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.924300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.730200</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.960400</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.878700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.078700</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.810800</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.018900</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.972200</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.824800</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.794700</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.996200</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.828700</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.804900</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.734000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.811500</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.682900</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.867300</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.573100</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.719200</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.887700</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.839600</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.931300</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.957500</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.839300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.672400</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.598500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.738500</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.773700</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.914200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.830700</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.681500</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.761000</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.937900</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.716200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.794700</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.896200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.918400</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.795500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.897400</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.787500</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.747600</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.750400</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.784200</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.853400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.748000</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.945600</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.814200</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.975700</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.774400</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.699700</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.849800</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.774700</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.605900</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.768300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.638000</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.866100</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.787300</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.780000</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.797400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.699100</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.768600</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.537200</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.722400</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.641100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.849900</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.608300</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.668300</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.832300</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.573200</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.673400</td>
#     </tr>
#     <tr>
#       <td>126<
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# ...
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 100, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %%
from unsloth import FastVisionModel
from transformers import AutoModel
import torch

BASE_MODEL = "unsloth/DeepSeek-OCR"   # hoặc deepseek-ai/deepseek-ocr
LORA_DIR = "lora_model"               # folder anh đã save

model, tokenizer = FastVisionModel.from_pretrained(
    model_name = BASE_MODEL,
    adapter_name = LORA_DIR,   # 🔑 CỰC KỲ QUAN TRỌNG
    load_in_4bit = False,
    auto_model = AutoModel,
    trust_remote_code = True,
)

FastVisionModel.for_inference(model)

print("Model + LoRA loaded")
# Out:
# A new version of the following files was downloaded from https://huggingface.co/unsloth/DeepSeek-OCR:
# - conversation.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/unsloth/DeepSeek-OCR:
# - deepencoder.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/unsloth/DeepSeek-OCR:
# - modeling_deepseekocr.py
# - conversation.py
# - deepencoder.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2025.12.9: Fast Deepseekocr patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Deepseekocr does not support SDPA - switching to fast eager.
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-000001.safetensors:   0%|          | 0.00/6.67G [00:00<?, ?B/s]
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at unsloth/DeepSeek-OCR and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/801 [00:00<?, ?B/s]
# Model + LoRA loaded

# %%
import os
import json

def load_hwdb_test(root_dir):
    samples = []

    # root_dir = .../test_data
    for sub in sorted(os.listdir(root_dir)):
        sub_dir = os.path.join(root_dir, sub)
        if not os.path.isdir(sub_dir):
            continue

        label_path = os.path.join(sub_dir, "label.json")
        if not os.path.exists(label_path):
            print("Missing label.json in", sub_dir)
            continue

        with open(label_path, "r", encoding="utf-8") as f:
            labels = json.load(f)

        for fname, gt_text in labels.items():
            img_path = os.path.join(sub_dir, fname)
            if not os.path.exists(img_path):
                print("Missing image:", img_path)
                continue

            samples.append({
                "image_path": img_path,
                "gt": gt_text
            })

    return samples

# %%
import os

def run_ocr(model, tokenizer, image_path):
    prompt = "\nFree OCR."

    output_path = "/tmp/ocr"
    os.makedirs(output_path, exist_ok=True)

    result = model.infer(
        tokenizer,
        prompt=prompt,
        image_file=image_path,
        output_path=output_path,
        image_size=640,
        base_size=1024,
        crop_mode=True,
        save_results=False, 
        test_compress=False,
        eval_mode=True,
    )

    print("DEBUG result:", result, type(result))

    if isinstance(result, str):
        return result.strip()
    elif isinstance(result, dict) and "text" in result:
        return result["text"].strip()
    elif hasattr(result, "text"):
        return result.text.strip()
    else:
        return ""

# %%
image_file = "/kaggle/input/dataset-vn-handwritten-ocr/Vietnamese_Handwritten_OCR/UIT_HWDB_line/UIT_HWDB_line/test_data/250/1.jpg"
pred_text = run_ocr(model, tokenizer, image_file)
print("PRED:", pred_text)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# DEBUG result: Thử thường, Bộ tài nguyên và môi trường Đảng Hùng Võ đãn đạo về: <class 'str'>
# PRED: Thử thường, Bộ tài nguyên và môi trường Đảng Hùng Võ đãn đạo về:

# %%
TEST_ROOT = "/kaggle/input/dataset-vn-handwritten-ocr/Vietnamese_Handwritten_OCR/UIT_HWDB_line/UIT_HWDB_line/test_data"

test_samples = load_hwdb_test(TEST_ROOT)
print("Total test samples:", len(test_samples))
print(test_samples[:2])
# Out:
# Total test samples: 201
# [{'image_path': '/kaggle/input/dataset-vn-handwritten-ocr/Vietnamese_Handwritten_OCR/UIT_HWDB_line/UIT_HWDB_line/test_data/250/1.jpg', 'gt': 'Thứ trưởng Bộ Tài nguyên & môi trường Đặng Hùng Võ tâm đắc với'}, {'image_path': '/kaggle/input/dataset-vn-handwritten-ocr/Vietnamese_Handwritten_OCR/UIT_HWDB_line/UIT_HWDB_line/test_data/250/2.jpg', 'gt': 'cơ chế " khuyến khích nhà đầu tư thỏa thuận với người sử dụng đất để nhận'}]

# %%
from tqdm import tqdm

results = []
for sample in tqdm(test_samples):
    try:
        pred = run_ocr(model, tokenizer, sample["image_path"])
    except Exception as e:
        print("Error:", sample["image_path"], e)
        pred = ""
    print("GT:", sample["gt"])
    print("PRED:", pred)
    results.append({"image": sample["image_path"], "gt": sample["gt"], "pred": pred})
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   0%|          | 1/201 [00:02<08:05,  2.43s/it]
# DEBUG result: Thử thường, Bộ tài nguyên và môi trường Đảng Hùng Võ đãn đạo về: <class 'str'>
# GT: Thứ trưởng Bộ Tài nguyên & môi trường Đặng Hùng Võ tâm đắc với
# PRED: Thử thường, Bộ tài nguyên và môi trường Đảng Hùng Võ đãn đạo về:
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   1%|          | 2/201 [00:05<08:43,  2.63s/it]
# DEBUG result: có thể "khuyến khích mua sắm từ thỏa thuận với những sản phẩm đặc thù nhân <class 'str'>
# GT: cơ chế " khuyến khích nhà đầu tư thỏa thuận với người sử dụng đất để nhận
# PRED: có thể "khuyến khích mua sắm từ thỏa thuận với những sản phẩm đặc thù nhân
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   1%|▏         | 3/201 [00:07<08:31,  2.58s/it]
# DEBUG result: chuyển những hoặc thực quyết sử dụng đất, nhân góp vốn bảng quyết sử <class 'str'>
# GT: chuyển nhượng hoặc thuê quyền sử dụng đất, nhận góp vốn bằng quyền sử
# PRED: chuyển những hoặc thực quyết sử dụng đất, nhân góp vốn bảng quyết sử
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   2%|▏         | 4/201 [00:10<08:39,  2.64s/it]
# DEBUG result: dùng đặt ... " Nhưng tại hôm ngày hôm qua, tiếng nói: hứ cái gì đó từ ngày <class 'str'>
# GT: dụng đất... " Nhưng tại hội nghị hôm qua, tiếng nói từ các sở tài nguyên
# PRED: dùng đặt ... " Nhưng tại hôm ngày hôm qua, tiếng nói: hứ cái gì đó từ ngày
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   2%|▏         | 5/201 [00:13<08:44,  2.67s/it]
# DEBUG result: và mới truyền lên thêm hành "boo" ở tiên chuẩn này ra lệch dù tháo. <class 'str'>
# GT: & môi trường lại đều đồng thanh " loại bỏ " điều khoản này ra khỏi dự thảo.
# PRED: và mới truyền lên thêm hành "boo" ở tiên chuẩn này ra lệch dù tháo.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   3%|▎         | 6/201 [00:15<08:17,  2.55s/it]
# DEBUG result: giám đốc Sở Tài nguyên và môi trường Hải phòng chương trình Tỉnh ch <class 'str'>
# GT: Giám đốc Sở Tài nguyên & môi trường Hải Phòng Chu Minh Tuấn cho
# PRED: giám đốc Sở Tài nguyên và môi trường Hải phòng chương trình Tỉnh ch
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   3%|▎         | 7/201 [00:17<08:02,  2.49s/it]
# DEBUG result: biết thành phố càng vững áp dụng các chữ "hoa" thành viên trong môi sở <class 'str'>
# GT: biết thành phố cảng từng áp dụng cơ chế " thỏa thuận " trong một số
# PRED: biết thành phố càng vững áp dụng các chữ "hoa" thành viên trong môi sở
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   4%|▍         | 8/201 [00:19<07:08,  2.22s/it]
# DEBUG result: ما هي النوعين الذي يظهر في هذه النمط؟ <class 'str'>
# GT: rất ít trường hợp, vậy mà đã gây phản ứng theo kiểu dây chuyền khá
# PRED: ما هي النوعين الذي يظهر في هذه النمط؟
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   4%|▍         | 9/201 [00:22<07:27,  2.33s/it]
# DEBUG result: mạnh : anh này nhìn trên rồi quay lại đôi nửa, anh lười thưa thưa. <class 'str'>
# GT: mạnh : anh này nhận tiền rồi quay lại đòi nữa, anh kia thỏa thuận
# PRED: mạnh : anh này nhìn trên rồi quay lại đôi nửa, anh lười thưa thưa.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   5%|▍         | 10/201 [00:23<06:43,  2.11s/it]
# DEBUG result: xong quay ra đời thoả thuận lại... <class 'str'>
# GT: xong quay ra đòi thỏa thuận lại...
# PRED: xong quay ra đời thoả thuận lại...
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   5%|▌         | 11/201 [00:25<06:49,  2.15s/it]
# DEBUG result: clima lúc ấy đã có một người đã nói chuyện "với nhau như <class 'str'>
# GT: Chưa kể để doanh nghiệp và người dân " nói chuyện " với nhau như
# PRED: clima lúc ấy đã có một người đã nói chuyện "với nhau như
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   6%|▌         | 12/201 [00:30<09:31,  3.03s/it]
# DEBUG result: سئو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو
# سئو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو، <class 'str'>
# GT: vậy, quyền của cơ quan quản lý nhà nước sẽ mất đi. " Tôi cũng có suy
# PRED: سئو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو
# سئو، گو، گو، گو، گو، گو، گو، گو، گو، گو، گو،
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   6%|▋         | 13/201 [00:33<08:45,  2.80s/it]
# DEBUG result: right" what doing chu"! Bo" there, you didn't say at the hot. Can't got the thing <class 'str'>
# GT: nghĩ như đồng chí " Bỏ được qui định này đi thì tốt. Cùng một lúc chúng
# PRED: right" what doing chu"! Bo" there, you didn't say at the hot. Can't got the thing
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   7%|▋         | 14/201 [00:35<08:33,  2.74s/it]
# DEBUG result: Ta thực hiện hai cố chế "của Nhà nước" thực hiện thủ đô, đã làm cách <class 'str'>
# GT: ta thực hiện hai cơ chế (vừa Nhà nước thực hiện thu hồi đất như cách
# PRED: Ta thực hiện hai cố chế "của Nhà nước" thực hiện thủ đô, đã làm cách
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   7%|▋         | 15/201 [00:38<08:22,  2.70s/it]
# DEBUG result: lên nay, vấn lịch giảng' khỏi nhà sáng hè thoả thương với người sử dụng <class 'str'>
# GT: làm lâu nay, vừa khuyến khích nhà đầu tư thỏa thuận với người sử dụng
# PRED: lên nay, vấn lịch giảng' khỏi nhà sáng hè thoả thương với người sử dụng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   8%|▊         | 16/201 [00:40<08:00,  2.60s/it]
# DEBUG result: tất) thì phải tạp - ông Trinh kiên Đình, phù gian sức so Tà <class 'str'>
# GT: đất) thì phức tạp - ông Trịnh Kiên Đĩnh, phó giám đốc Sở Tài
# PRED: tất) thì phải tạp - ông Trinh kiên Đình, phù gian sức so Tà
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   8%|▊         | 17/201 [00:43<07:39,  2.50s/it]
# DEBUG result: Nguyệt – một thư ơ ng và nhà sách Hà Nội, liên đề ng. <class 'str'>
# GT: nguyên - môi trường và nhà đất Hà Nội, lên tiếng.
# PRED: Nguyệt – một thư ơ ng và nhà sách Hà Nội, liên đề ng.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   9%|▉         | 18/201 [00:45<07:31,  2.47s/it]
# DEBUG result: Páo từ, lập thường cần cả quan sao cho, Thử trường bằng thông với kháng chất. <class 'str'>
# GT: Bảo vệ lập trường của cơ quan soạn thảo, Thứ trưởng Đặng Hùng Võ khẳng định
# PRED: Páo từ, lập thường cần cả quan sao cho, Thử trường bằng thông với kháng chất.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#   9%|▉         | 19/201 [00:48<07:40,  2.53s/it]
# DEBUG result: "Trường hợp nào đánh tên cơ mà cần thêm phương viên người đang trả đồng đặt, chúng <class 'str'>
# GT: " trường hợp nhà đầu tư có nhu cầu thỏa thuận với người đang sử dụng đất, chúng
# PRED: "Trường hợp nào đánh tên cơ mà cần thêm phương viên người đang trả đồng đặt, chúng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  10%|▉         | 20/201 [00:51<07:57,  2.64s/it]
# DEBUG result: ta cán lưỡng lồch từ Nhà mặc chẳng mất cái gì cả". Ông vỡ "kêu gọi": <class 'str'>
# GT: ta cần khuyến khích vì Nhà nước chẳng mất cái gì cả ". Ông Võ " kêu gọi " :
# PRED: ta cán lưỡng lồch từ Nhà mặc chẳng mất cái gì cả". Ông vỡ "kêu gọi":
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  10%|█         | 21/201 [00:53<07:34,  2.52s/it]
# DEBUG result: chúng ta còn thay đổi trong quan điểm, không nên đọc thông hành chính <class 'str'>
# GT: chúng ta cần thay đổi trong quan điểm, không nên để hệ thống hành chính
# PRED: chúng ta còn thay đổi trong quan điểm, không nên đọc thông hành chính
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  11%|█         | 22/201 [00:56<07:45,  2.60s/it]
# DEBUG result: Ôm viếm nhéi quá, bởi ôm càng nhéi thì sai càng nhéi, Bí trưng Mai <class 'str'>
# GT: ôm về mình nhiều quá, bởi ôm càng nhiều thì sai càng nhiều. Bộ trưởng Mai
# PRED: Ôm viếm nhéi quá, bởi ôm càng nhéi thì sai càng nhéi, Bí trưng Mai
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  11%|█▏        | 23/201 [00:58<07:49,  2.64s/it]
# DEBUG result: Ai truc tipp léti: Che muốc đánh đp đúng có chi tiết thao thang khi thưởi. <class 'str'>
# GT: Ái Trực tiếp lời : Các nước đều áp dụng cơ chế tự thỏa thuận khi thu hồi
# PRED: Ai truc tipp léti: Che muốc đánh đp đúng có chi tiết thao thang khi thưởi.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
#  12%|█▏        | 24/201 [00:59<06:11,  2.10s/it]
# DEBUG result: 盐 <class 'str'>
# GT: đất.
# PRED: 盐
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  12%|█▏        | 25/201 [01:01<06:21,  2.17s/it]
# DEBUG result: Ngay cả trường hợp ta không qui định, người dân về doanh nghiệp vẫn thực hiện <class 'str'>
# GT: Ngay cả trường hợp ta không qui định, người dân và doanh nghiệp vẫn thực hiện
# PRED: Ngay cả trường hợp ta không qui định, người dân về doanh nghiệp vẫn thực hiện
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  13%|█▎        | 26/201 [01:04<06:46,  2.32s/it]
# DEBUG result: có đặc này. "Nếu có dùng quyển lúc hành chính nhà mặc vội mở hành khôn <class 'str'>
# GT: cơ chế này. " Nếu cứ dùng quyền lực hành chính nhà nước với mô hình khuôn
# PRED: có đặc này. "Nếu có dùng quyển lúc hành chính nhà mặc vội mở hành khôn
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  13%|█▎        | 27/201 [01:07<07:19,  2.53s/it]
# DEBUG result: cùng, người dân sức kêu " - ông Trúc nói. Chuyện "bò" - "con". Phó Giám đốc: <class 'str'>
# GT: cứng, người dân sẽ kêu " - ông Trực nói. Chuyện " bố " - " con ". Phó giám đốc
# PRED: cùng, người dân sức kêu " - ông Trúc nói. Chuyện "bò" - "con". Phó Giám đốc:
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  14%|█▍        | 28/201 [01:10<07:26,  2.58s/it]
# DEBUG result: 3. Tài nguyên - môi trường ở nhà đất thế Nội Trung. Kiến Điều đặc nghệ: thời <class 'str'>
# GT: Sở Tài nguyên - môi trường & nhà đất Hà Nội Trịnh Kiên Đĩnh đề nghị : thẩm
# PRED: 3. Tài nguyên - môi trường ở nhà đất thế Nội Trung. Kiến Điều đặc nghệ: thời
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  14%|█▍        | 29/201 [01:13<07:38,  2.67s/it]
# DEBUG result: quyên thư hồi: đặt, giao đặt phí: đúc thẻ hiện theo tính "ứng lời" bao trùm <class 'str'>
# GT: quyền thu hồi đất, giao đất phải được thể hiện theo tinh thần " ông bố bao trùm
# PRED: quyên thư hồi: đặt, giao đặt phí: đúc thẻ hiện theo tính "ứng lời" bao trùm
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  15%|█▍        | 30/201 [01:16<07:44,  2.72s/it]
# DEBUG result: Đừng còn ấy. Theo đó, UBND cấp tỉnh, thành phố được quyền thu hồi, giao dịch <class 'str'>
# GT: ông con ". Theo đó, UBND cấp tỉnh, thành phố được quyền thu hồi, giao đất
# PRED: Đừng còn ấy. Theo đó, UBND cấp tỉnh, thành phố được quyền thu hồi, giao dịch
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  15%|█▌        | 31/201 [01:18<07:39,  2.70s/it]
# DEBUG result: thus: thăm quyền của UBND cấp quận, huyện (Thay ơi qui định như thế trên nay, <class 'str'>
# GT: thuộc thẩm quyền của UBND cấp quận, huyện (thay vì qui định như hiện nay,
# PRED: thus: thăm quyền của UBND cấp quận, huyện (Thay ơi qui định như thế trên nay,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  16%|█▌        | 32/201 [01:21<07:45,  2.76s/it]
# DEBUG result: "Ởng bố "mưa lạm đời ngày phải thông báo cho "ông con" thức thân, vừa nhìn <class 'str'>
# GT: " ông bố " muốn làm điều này phải thông báo cho " ông con " thực hiện, vừa nhiêu
# PRED: "Ởng bố "mưa lạm đời ngày phải thông báo cho "ông con" thức thân, vừa nhìn
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  16%|█▋        | 33/201 [01:23<07:06,  2.54s/it]
# DEBUG result: bỏ qua không thời gian thường đi các cách thủ tục thành chuẩn). <class 'str'>
# GT: khê vừa không thể hiện hướng đi cải cách thủ tục hành chính).
# PRED: bỏ qua không thời gian thường đi các cách thủ tục thành chuẩn).
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  17%|█▋        | 34/201 [01:25<06:45,  2.43s/it]
# DEBUG result: Tap the third button. Doing thing us plan ding: "ong bo" or quyen cua "ong bo". <class 'str'>
# GT: Lập tức Thứ trưởng Đặng Hùng Võ phản ứng : " ông bố " có quyền của " ông bố ",
# PRED: Tap the third button. Doing thing us plan ding: "ong bo" or quyen cua "ong bo".
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  17%|█▋        | 35/201 [01:28<07:08,  2.58s/it]
# DEBUG result: “Bóng con” có quyển của “bóng con”. Lượt không cho phép “sợi bỏ” làm thay “sợi <class 'str'>
# GT: " ông con " có quyền của " ông con ". Luật không cho phép " ông bố " làm thay " ông
# PRED: “Bóng con” có quyển của “bóng con”. Lượt không cho phép “sợi bỏ” làm thay “sợi
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  18%|█▊        | 36/201 [01:31<06:54,  2.51s/it]
# DEBUG result: con". Trường hợp nào lành-thay là phạm luật, thì có tiêu biểu hợp này sẽ ứng <class 'str'>
# GT: con ". Trường hợp nào làm thay là phạm luật, chỉ có điều hiện nay các " ông
# PRED: con". Trường hợp nào lành-thay là phạm luật, thì có tiêu biểu hợp này sẽ ứng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
#  18%|█▊        | 37/201 [01:32<06:04,  2.22s/it]
# DEBUG result: con "khiêng đám hiền mà thôi !" <class 'str'>
# GT: con " không dám kêu mà thôi!
# PRED: con "khiêng đám hiền mà thôi !"
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  19%|█▉        | 38/201 [01:35<06:15,  2.31s/it]
# DEBUG result: Chúng tôi trinh hành động thực hiện Nghị quyết trung ương 9-4hóa. <class 'str'>
# GT: Chương trình hành động thực hiện Nghị quyết trung ương 9 - khóa
# PRED: Chúng tôi trinh hành động thực hiện Nghị quyết trung ương 9-4hóa.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  19%|█▉        | 39/201 [01:37<06:18,  2.34s/it]
# DEBUG result: IX của Đảng bộ TP.HCM về xây dựng Đảng: tiếp tục chỉ đạo mạnh, <class 'str'>
# GT: IX của Đảng bộ TP.HCM Về xây dựng Đảng : tiếp tục chỉ đạo mạnh
# PRED: IX của Đảng bộ TP.HCM về xây dựng Đảng: tiếp tục chỉ đạo mạnh,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  20%|█▉        | 40/201 [01:40<06:29,  2.42s/it]
# DEBUG result: mẹ, có hiểu quả cuộc văn tượng xây dựng chính tôn Đảng theo tinh <class 'str'>
# GT: mẽ, có hiệu quả cuộc vận động xây dựng chỉnh đốn Đảng theo tinh
# PRED: mẹ, có hiểu quả cuộc văn tượng xây dựng chính tôn Đảng theo tinh
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  20%|██        | 41/201 [01:42<06:35,  2.47s/it]
# DEBUG result: thân nghĩ quyết trung vương 6 (lần số). Theo đó, tiếp tục thực hiện việc <class 'str'>
# GT: thần nghị quyết trung ương 6 (lần 2). Theo đó, tiếp tục thực hiện việc
# PRED: thân nghĩ quyết trung vương 6 (lần số). Theo đó, tiếp tục thực hiện việc
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  21%|██        | 42/201 [01:45<06:39,  2.51s/it]
# DEBUG result: Lời khai nhà đất và cô sợ xin nuôi tình doanh của bạn bố - cô gái. <class 'str'>
# GT: kê khai nhà đất và cơ sở sản xuất kinh doanh của cán bộ - công chức;
# PRED: Lời khai nhà đất và cô sợ xin nuôi tình doanh của bạn bố - cô gái.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  21%|██▏       | 43/201 [01:47<06:30,  2.47s/it]
# DEBUG result: tăng cường thành thêm tra những nơi có dấu hiệu vi phạm, tác biến <class 'str'>
# GT: tăng cường thanh kiểm tra những nơi có dấu hiệu vi phạm, đặc biệt
# PRED: tăng cường thành thêm tra những nơi có dấu hiệu vi phạm, tác biến
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  22%|██▏       | 44/201 [01:49<06:01,  2.30s/it]
# DEBUG result: trong linh viết đặt đại và cái cùng trình trong điển. <class 'str'>
# GT: trong lĩnh vực đất đai và các công trình trọng điểm.
# PRED: trong linh viết đặt đại và cái cùng trình trong điển.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  22%|██▏       | 45/201 [01:51<05:58,  2.30s/it]
# DEBUG result: Xin lý nghiem minh, cho pháp luật và kỹ luật của Đảng những người <class 'str'>
# GT: Xử lý nghiêm minh theo pháp luật và kỷ luật của Đảng những người
# PRED: Xin lý nghiem minh, cho pháp luật và kỹ luật của Đảng những người
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  23%|██▎       | 46/201 [01:54<06:01,  2.34s/it]
# DEBUG result: có hành vi sai trái và những người bao che. Thủ tục hiện tốt cả quy định, <class 'str'>
# GT: có hành vi sai trái và những người bao che. Thực hiện tốt các quy định
# PRED: có hành vi sai trái và những người bao che. Thủ tục hiện tốt cả quy định,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  23%|██▎       | 47/201 [01:57<06:25,  2.50s/it]
# DEBUG result: tôi vẫn vui vẻ bà lành đạo, quản lý đời xây ra tham nhũng, tiêu cực ở cả <class 'str'>
# GT: đối với cán bộ lãnh đạo, quản lý để xảy ra tham nhũng, tiêu cực ở cơ
# PRED: tôi vẫn vui vẻ bà lành đạo, quản lý đời xây ra tham nhũng, tiêu cực ở cả
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  24%|██▍       | 48/201 [01:59<06:16,  2.46s/it]
# DEBUG result: man: Lên vị. Kiên toan và tăng uống sức chiến đấu của tổ chức <class 'str'>
# GT: quan, đơn vị. Kiện toàn và tăng cường sức chiến đấu của tổ chức
# PRED: man: Lên vị. Kiên toan và tăng uống sức chiến đấu của tổ chức
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  24%|██▍       | 49/201 [02:02<06:23,  2.52s/it]
# DEBUG result: c8 33 Đăng. Túp tục đôi mới và măng cao công tác cán bộ. Túp tục <class 'str'>
# GT: cơ sở Đảng. Tiếp tục đổi mới và nâng cao công tác cán bộ. Tiếp tục
# PRED: c8 33 Đăng. Túp tục đôi mới và măng cao công tác cán bộ. Túp tục
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  25%|██▍       | 50/201 [02:04<06:04,  2.42s/it]
# DEBUG result: tôi mới phường thức lành tạo của cáp úy đang theo phường chân. <class 'str'>
# GT: đổi mới phương thức lãnh đạo của cấp ủy Đảng theo phương châm
# PRED: tôi mới phường thức lành tạo của cáp úy đang theo phường chân.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
#  25%|██▌       | 51/201 [02:05<05:05,  2.04s/it]
# DEBUG result: thường manh về cả sở. <class 'str'>
# GT: hướng mạnh về cơ sở.
# PRED: thường manh về cả sở.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  26%|██▌       | 52/201 [02:08<05:27,  2.20s/it]
# DEBUG result: Về cái cách hành chính: Tập trung chân chính mạnh hơn mùa đại cường. <class 'str'>
# GT: Về cải cách hành chính : Tập trung chấn chỉnh mạnh hơn nữa kỷ cương,
# PRED: Về cái cách hành chính: Tập trung chân chính mạnh hơn mùa đại cường.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  26%|██▋       | 53/201 [02:10<05:28,  2.22s/it]
# DEBUG result: hỷ luật trong bà mày hành chính, nàng cao tính thân trách nhiệm và <class 'str'>
# GT: kỷ luật trong bộ máy hành chính, nâng cao tinh thần trách nhiệm và
# PRED: hỷ luật trong bà mày hành chính, nàng cao tính thân trách nhiệm và
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  27%|██▋       | 54/201 [02:12<05:39,  2.31s/it]
# DEBUG result: Ở thực hiện luật của CO-CC, nhật la trên lĩnh vực nhà đất, đâu? <class 'str'>
# GT: ý thức kỷ luật của CB - CC, nhất là trên lĩnh vực nhà đất, đầu tư,
# PRED: Ở thực hiện luật của CO-CC, nhật la trên lĩnh vực nhà đất, đâu?
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  27%|██▋       | 55/201 [02:15<05:43,  2.35s/it]
# DEBUG result: mình doanh, trảt tư vậy đúng và giải quyết khiếu nại, tớ cạo. <class 'str'>
# GT: kinh doanh, trật tự xây dựng và giải quyết khiếu nại, tố cáo.
# PRED: mình doanh, trảt tư vậy đúng và giải quyết khiếu nại, tớ cạo.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  28%|██▊       | 56/201 [02:18<05:51,  2.43s/it]
# DEBUG result: Kỳ duy thơm thẹn hè thông ca' quy tinh thú tục hạnh chính. <class 'str'>
# GT: Xây dựng hoàn thiện hệ thống các qui trình thủ tục hành chính.
# PRED: Kỳ duy thơm thẹn hè thông ca' quy tinh thú tục hạnh chính.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
#  28%|██▊       | 57/201 [02:20<05:42,  2.38s/it]
# DEBUG result: Kêu vậy ít chán chính bị mày hành chính cái cáp, mành chóng <class 'str'>
# GT: Kiên quyết chấn chỉnh bộ máy hành chính các cấp, nhanh chóng
# PRED: Kêu vậy ít chán chính bị mày hành chính cái cáp, mành chóng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  29%|██▉       | 58/201 [02:22<05:36,  2.35s/it]
# DEBUG result: Nhà chủ phục tinh tráng quan liêu, cửa quyên, thách đinh. <class 'str'>
# GT: khắc phục tình trạng quan liêu, cửa quyền, hách dịch.
# PRED: Nhà chủ phục tinh tráng quan liêu, cửa quyên, thách đinh.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  29%|██▉       | 59/201 [02:24<05:29,  2.32s/it]
# DEBUG result: Xây dựng và phát triển dân tộc CB-CC có chất lượng chuyên môn <class 'str'>
# GT: Xây dựng và phát triển đội ngũ CB - CC có chất lượng chuyên môn
# PRED: Xây dựng và phát triển dân tộc CB-CC có chất lượng chuyên môn
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  30%|██▉       | 60/201 [02:27<05:48,  2.47s/it]
# DEBUG result: eao, eô phạm chát, tạo đức. Kiếm tra, xử lý hưu quyết cái ưu <class 'str'>
# GT: cao, có phẩm chất, đạo đức. Kiểm tra, xử lý kiên quyết các vụ
# PRED: eao, eô phạm chát, tạo đức. Kiếm tra, xử lý hưu quyết cái ưu
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  30%|███       | 61/201 [02:29<05:37,  2.41s/it]
# DEBUG result: tham nhúng, làng phí, làm thật thoát tài sản nhà nước... Viênh <class 'str'>
# GT: tham nhũng, lãng phí, làm thất thoát tài sản nhà nước... Về kinh
# PRED: tham nhúng, làng phí, làm thật thoát tài sản nhà nước... Viênh
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  31%|███       | 62/201 [02:32<05:36,  2.42s/it]
# DEBUG result: Tôi: Tập trung mới nổi tiếc nhằm thao gỗ sản xuất như doanh, <class 'str'>
# GT: tế : Tập trung mọi nỗ lực nhằm tháo gỡ sản xuất kinh doanh,
# PRED: Tôi: Tập trung mới nổi tiếc nhằm thao gỗ sản xuất như doanh,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  31%|███▏      | 63/201 [02:34<05:39,  2.46s/it]
# DEBUG result: Hợp tác tôi đã tăng trưởng ODP trên địa bàn TP đạt 16% năm. <class 'str'>
# GT: đưa tốc độ tăng trưởng GDP trên địa bàn TP đạt 12% năm
# PRED: Hợp tác tôi đã tăng trưởng ODP trên địa bàn TP đạt 16% năm.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  32%|███▏      | 64/201 [02:37<05:38,  2.47s/it]
# DEBUG result: 2004 vua triển 1,5% năm 2005. Thật triển nhưng cái ngân dịch vụ <class 'str'>
# GT: 2004 và trên 12% năm 2005. Phát triển nhanh các ngành dịch vụ,
# PRED: 2004 vua triển 1,5% năm 2005. Thật triển nhưng cái ngân dịch vụ
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
#  32%|███▏      | 65/201 [02:38<04:57,  2.18s/it]
# DEBUG result: tài cầu trúc cái ngành công nghiệp. <class 'str'>
# GT: tái cấu trúc các ngành công nghiệp.
# PRED: tài cầu trúc cái ngành công nghiệp.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  33%|███▎      | 66/201 [02:41<05:09,  2.30s/it]
# DEBUG result: Tiếp tục nhân rộng, cái mỏ hình huy động vẫn dâu tù. Tập trung khai <class 'str'>
# GT: Tiếp tục nhân rộng các mô hình huy động vốn đầu tư. Tập trung khai
# PRED: Tiếp tục nhân rộng, cái mỏ hình huy động vẫn dâu tù. Tập trung khai
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  33%|███▎      | 67/201 [02:43<05:14,  2.34s/it]
# DEBUG result: thai cái nguồn với cho ngàn sách. Từng hết quả tính có phản hại. <class 'str'>
# GT: thác các nguồn vốn cho ngân sách. Tổng kết quá trình cổ phần hóa
# PRED: thai cái nguồn với cho ngàn sách. Từng hết quả tính có phản hại.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  34%|███▍      | 68/201 [02:46<05:13,  2.36s/it]
# DEBUG result: doanh nghiệp nhà nước và việc tổ chức tập xếp lại doanh nghiệp nhà <class 'str'>
# GT: doanh nghiệp nhà nước và việc tổ chức sắp xếp lại doanh nghiệp nhà
# PRED: doanh nghiệp nhà nước và việc tổ chức tập xếp lại doanh nghiệp nhà
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  34%|███▍      | 69/201 [02:49<05:50,  2.66s/it]
# DEBUG result: mùát. Trực định gượt đánh của TP vị một số chính sách của đưa <class 'str'>
# GT: nước. Triển khai quyết định của TP về một số chính sách ưu đãi
# PRED: mùát. Trực định gượt đánh của TP vị một số chính sách của đưa
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
#  35%|███▍      | 70/201 [02:52<05:47,  2.65s/it]
# DEBUG result: tôi vớt cái ấn cố vớt tấm tấn niềc ngại. Khi sát lại chúng <class 'str'>
# GT: đối với các dự án có vốn đầu tư nước ngoài. Rà soát lại chương
# PRED: tôi vớt cái ấn cố vớt tấm tấn niềc ngại. Khi sát lại chúng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  35%|███▌      | 71/201 [02:54<05:41,  2.63s/it]
# DEBUG result: tành hồi nhập hình tế của TP. Về văn hoá - xã hội: dạy môn <class 'str'>
# GT: trình hội nhập kinh tế của TP. Về văn hóa - xã hội : đẩy mạnh
# PRED: tành hồi nhập hình tế của TP. Về văn hoá - xã hội: dạy môn
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  36%|███▌      | 72/201 [02:57<05:32,  2.57s/it]
# DEBUG result: cả hồi hoá, phát triển xã hội học tập, vận tải dân trú ngân <class 'str'>
# GT: xã hội hóa, phát triển xã hội học tập, ưu tiên đầu tư ngân
# PRED: cả hồi hoá, phát triển xã hội học tập, vận tải dân trú ngân
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
#  36%|███▋      | 73/201 [02:58<04:46,  2.24s/it]
# DEBUG result: Lạch cho giả dục - đào tạo. <class 'str'>
# GT: sách cho giáo dục - đào tạo.
# PRED: Lạch cho giả dục - đào tạo.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  37%|███▋      | 74/201 [03:01<04:49,  2.28s/it]
# DEBUG result: Nàng cao nàng lâu quàn lấy nhà nuốt trên cái lính vúc kính danh. <class 'str'>
# GT: Nâng cao năng lực quản lý nhà nước trên các lĩnh vực kinh doanh
# PRED: Nàng cao nàng lâu quàn lấy nhà nuốt trên cái lính vúc kính danh.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  37%|███▋      | 75/201 [03:03<05:01,  2.39s/it]
# DEBUG result: dịch vụ xin khoẻ; khuyến phục những sở thờ, tiêu cực trong quản lý. <class 'str'>
# GT: dịch vụ văn hóa; khắc phục những sơ hở, tiêu cực trong quản lý
# PRED: dịch vụ xin khoẻ; khuyến phục những sở thờ, tiêu cực trong quản lý.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  38%|███▊      | 76/201 [03:06<04:53,  2.35s/it]
# DEBUG result: và hoạt động văn hoá. Trái tục tập trung người lực cho chúng <class 'str'>
# GT: và hoạt động văn hóa. Tiếp tục tập trung nguồn lực cho chương
# PRED: và hoạt động văn hoá. Trái tục tập trung người lực cho chúng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
#  38%|███▊      | 77/201 [03:07<03:59,  1.93s/it]
# DEBUG result: tinh 3 gian... <class 'str'>
# GT: trình 3 giảm...
# PRED: tinh 3 gian...
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  39%|███▉      | 78/201 [03:09<04:27,  2.17s/it]
# DEBUG result: Chương trình hành động thực hiện Nghị quyết trung ương 9 - thứ 1x của Đảng 15. <class 'str'>
# GT: Chương trình hành động thực hiện Nghị quyết trung ương 9 - khóa IX của Đảng bộ
# PRED: Chương trình hành động thực hiện Nghị quyết trung ương 9 - thứ 1x của Đảng 15.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  39%|███▉      | 79/201 [03:12<04:50,  2.38s/it]
# DEBUG result: Trước về xây dựng bảng: tiếp tục chỉ đạo mạnh mẽ, có hiệu quả các văn dạng vụ <class 'str'>
# GT: TP.HCM Về xây dựng Đảng : tiếp tục chỉ đạo mạnh mẽ, có hiệu quả cuộc vận động xây
# PRED: Trước về xây dựng bảng: tiếp tục chỉ đạo mạnh mẽ, có hiệu quả các văn dạng vụ
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  40%|███▉      | 80/201 [03:15<04:59,  2.47s/it]
# DEBUG result: dùng chữa đơn Đăng theo trình thời ngữ: trung ương 6 (1a2). Theo đó, tập trung <class 'str'>
# GT: dựng chỉnh đốn Đảng theo tinh thần nghị quyết trung ương 6 (lần 2). Theo đó, tiếp tục
# PRED: dùng chữa đơn Đăng theo trình thời ngữ: trung ương 6 (1a2). Theo đó, tập trung
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  40%|████      | 81/201 [03:18<05:09,  2.58s/it]
# DEBUG result: mặc thần việc kẻ thái nhà đặt ra có sở sản xuất linh danh của cán bộ - cộng <class 'str'>
# GT: thực hiện việc kê khai nhà đất và cơ sở sản xuất kinh doanh của cán bộ - công
# PRED: mặc thần việc kẻ thái nhà đặt ra có sở sản xuất linh danh của cán bộ - cộng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  41%|████      | 82/201 [03:20<05:01,  2.53s/it]
# DEBUG result: what; taking care; thank him; I am thinking; not; do; do; him; vi; them; vi; them; <class 'str'>
# GT: chức; tăng cường thanh kiểm tra những nơi có dấu hiệu vi phạm, đặc biệt
# PRED: what; taking care; thank him; I am thinking; not; do; do; him; vi; them; vi; them;
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  41%|████▏     | 83/201 [03:22<04:36,  2.34s/it]
# DEBUG result: đừng lắm vì các đại và các công trình trong đời. <class 'str'>
# GT: trong lĩnh vực đất đai và các công trình trọng điểm.
# PRED: đừng lắm vì các đại và các công trình trong đời.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  42%|████▏     | 84/201 [03:24<04:37,  2.37s/it]
# DEBUG result: Xùi lý nghiêm mình theo pháp luật và kỷ luật của Đảng những người có hạn <class 'str'>
# GT: Xử lý nghiêm minh theo pháp luật và kỷ luật của Đảng những người có hành
# PRED: Xùi lý nghiêm mình theo pháp luật và kỷ luật của Đảng những người có hạn
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  42%|████▏     | 85/201 [03:27<04:46,  2.47s/it]
# DEBUG result: vì sai trái và nhúng ngầu bao che. Thử hiện tới các quy định đó! Bạn cần bị lãnh <class 'str'>
# GT: vi sai trái và những người bao che. Thực hiện tốt các quy định đối với cán bộ lãnh
# PRED: vì sai trái và nhúng ngầu bao che. Thử hiện tới các quy định đó! Bạn cần bị lãnh
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  43%|████▎     | 86/201 [03:30<05:02,  2.63s/it]
# DEBUG result: Tao, quan lý dê' xay ra tham nhung, tiêu ưc d cô quan, đôn ơi'. Kiên toan ư <class 'str'>
# GT: đạo, quản lý để xảy ra tham nhũng, tiêu cực ở cơ quan, đơn vị. Kiện toàn và
# PRED: Tao, quan lý dê' xay ra tham nhung, tiêu ưc d cô quan, đôn ơi'. Kiên toan ư
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  43%|████▎     | 87/201 [03:33<04:58,  2.62s/it]
# DEBUG result: tăng cường sức chiến đấu và tạo thúc đẩy. Tập tục tới mức và năng <class 'str'>
# GT: tăng cường sức chiến đấu của tổ chức cơ sở Đảng. Tiếp tục đổi mới và nâng
# PRED: tăng cường sức chiến đấu và tạo thúc đẩy. Tập tục tới mức và năng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  44%|████▍     | 88/201 [03:35<04:53,  2.60s/it]
# DEBUG result: cao công tác cán bộ. Tiếp tục đổi mới phương thức làm tạo cơ cấp ủy <class 'str'>
# GT: cao công tác cán bộ. Tiếp tục đổi mới phương thức lãnh đạo của cấp ủy
# PRED: cao công tác cán bộ. Tiếp tục đổi mới phương thức làm tạo cơ cấp ủy
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
#  44%|████▍     | 89/201 [03:37<04:12,  2.26s/it]
# DEBUG result: Đang theo phương châm thường mang về có số. <class 'str'>
# GT: Đảng theo phương châm hướng mạnh về cơ sở.
# PRED: Đang theo phương châm thường mang về có số.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  45%|████▍     | 90/201 [03:40<04:34,  2.48s/it]
# DEBUG result: Viê cai câch hanh chinh : Tâp trung chân chinh manh hôn nữa têj cung, bị hút trong <class 'str'>
# GT: Về cải cách hành chính : Tập trung chấn chỉnh mạnh hơn nữa kỷ cương, kỷ luật trong
# PRED: Viê cai câch hanh chinh : Tâp trung chân chinh manh hôn nữa têj cung, bị hút trong
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  45%|████▌     | 91/201 [03:42<04:28,  2.44s/it]
# DEBUG result: be may hans shins, nang cao tins than trach nhim va y thuc ty duu ua cbc <class 'str'>
# GT: bộ máy hành chính, nâng cao tinh thần trách nhiệm và ý thức kỷ luật của CB - CC,
# PRED: be may hans shins, nang cao tins than trach nhim va y thuc ty duu ua cbc
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  46%|████▌     | 92/201 [03:44<04:22,  2.41s/it]
# DEBUG result: nhai la tren linh viec nha dai, dau thi, em doanh, trai tu xay dung oa <class 'str'>
# GT: nhất là trên lĩnh vực nhà đất, đầu tư, kinh doanh, trật tự xây dựng và
# PRED: nhai la tren linh viec nha dai, dau thi, em doanh, trai tu xay dung oa
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  46%|████▋     | 93/201 [03:47<04:32,  2.52s/it]
# DEBUG result: già: quyết thiếu nai, tó câo. Xây dựng hoàn thiện hệ thay các quy trịc <class 'str'>
# GT: giải quyết khiếu nại, tố cáo. Xây dựng hoàn thiện hệ thống các qui trình
# PRED: già: quyết thiếu nai, tó câo. Xây dựng hoàn thiện hệ thay các quy trịc
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  47%|████▋     | 94/201 [03:50<04:27,  2.50s/it]
# DEBUG result: Thủ tục hành chính. Kiên quyết thành chính bỏ máy hành chính cất cấy <class 'str'>
# GT: thủ tục hành chính. Kiên quyết chấn chỉnh bộ máy hành chính các cấp,
# PRED: Thủ tục hành chính. Kiên quyết thành chính bỏ máy hành chính cất cấy
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  47%|████▋     | 95/201 [03:52<04:18,  2.44s/it]
# DEBUG result: nhans chóng thác phục tình trạng quan liêu, của quyền, khách dịch. <class 'str'>
# GT: nhanh chóng khắc phục tình trạng quan liêu, cửa quyền, hách dịch.
# PRED: nhans chóng thác phục tình trạng quan liêu, của quyền, khách dịch.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  48%|████▊     | 96/201 [03:55<04:19,  2.47s/it]
# DEBUG result: Xây dựng và phát triển đời ngữ CB-cc có chất lượng chuyên môn cao, có phẩm. <class 'str'>
# GT: Xây dựng và phát triển đội ngũ CB - CC có chất lượng chuyên môn cao, có phẩm
# PRED: Xây dựng và phát triển đời ngữ CB-cc có chất lượng chuyên môn cao, có phẩm.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  48%|████▊     | 97/201 [03:57<04:26,  2.56s/it]
# DEBUG result: chài, tạo đức. kiếm tra, xử lý kiến quyết các cử tham nhũng, lòng phụ <class 'str'>
# GT: chất, đạo đức. Kiểm tra, xử lý kiên quyết các vụ tham nhũng, lãng phí,
# PRED: chài, tạo đức. kiếm tra, xử lý kiến quyết các cử tham nhũng, lòng phụ
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  49%|████▉     | 98/201 [04:00<04:27,  2.60s/it]
# DEBUG result: Lam thai' thoát tay. Sản nhà nước ..... Về bình tiếc! tập trung mới nổi lúc <class 'str'>
# GT: làm thất thoát tài sản nhà nước... Về kinh tế : Tập trung mọi nỗ lực
# PRED: Lam thai' thoát tay. Sản nhà nước ..... Về bình tiếc! tập trung mới nổi lúc
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  49%|████▉     | 99/201 [04:02<04:22,  2.57s/it]
# DEBUG result: nhằm tháo gỡ sản xuất kinh doanh, đầu tư tổng thống GDP trên địa <class 'str'>
# GT: nhằm tháo gỡ sản xuất kinh doanh, đưa tốc độ tăng trưởng GDP trên địa
# PRED: nhằm tháo gỡ sản xuất kinh doanh, đầu tư tổng thống GDP trên địa
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  50%|████▉     | 100/201 [04:05<04:14,  2.52s/it]
# DEBUG result: bản TP đạt 12% năm 2004 và trên 12% năm 2005. Phải tiến hành <class 'str'>
# GT: bàn TP đạt 12% năm 2004 và trên 12% năm 2005. Phát triển nhanh
# PRED: bản TP đạt 12% năm 2004 và trên 12% năm 2005. Phải tiến hành
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  50%|█████     | 101/201 [04:07<03:58,  2.39s/it]
# DEBUG result: các ngành dịch vụ, tài chủ trực tiếp công nghiệp. <class 'str'>
# GT: các ngành dịch vụ, tái cấu trúc các ngành công nghiệp.
# PRED: các ngành dịch vụ, tài chủ trực tiếp công nghiệp.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  51%|█████     | 102/201 [04:09<03:59,  2.42s/it]
# DEBUG result: Tiếp tục nhàn răng các mô hình, huy động với đài tắt. Tập trung khai thác <class 'str'>
# GT: Tiếp tục nhân rộng các mô hình huy động vốn đầu tư. Tập trung khai thác
# PRED: Tiếp tục nhàn răng các mô hình, huy động với đài tắt. Tập trung khai thác
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  51%|█████     | 103/201 [04:12<03:58,  2.43s/it]
# DEBUG result: các người với cho người sách. Tổng kết quả trực ốp phải hoá doanh <class 'str'>
# GT: các nguồn vốn cho ngân sách. Tổng kết quá trình cổ phần hóa doanh
# PRED: các người với cho người sách. Tổng kết quả trực ốp phải hoá doanh
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  52%|█████▏    | 104/201 [04:14<03:57,  2.45s/it]
# DEBUG result: rghiep nha nuoc va viec to' chu', sap xep loi doanng hiep nha nuoc. <class 'str'>
# GT: nghiệp nhà nước và việc tổ chức sắp xếp lại doanh nghiệp nhà nước.
# PRED: rghiep nha nuoc va viec to' chu', sap xep loi doanng hiep nha nuoc.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  52%|█████▏    | 105/201 [04:17<03:53,  2.44s/it]
# DEBUG result: Trên bhai quyết tình của TP về môi sắc đình sách du đạt đời vui. <class 'str'>
# GT: Triển khai quyết định của TP về một số chính sách ưu đãi đối với
# PRED: Trên bhai quyết tình của TP về môi sắc đình sách du đạt đời vui.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  53%|█████▎    | 106/201 [04:19<03:49,  2.42s/it]
# DEBUG result: các dữ án có vốn đầu tư nước ngoài. Rà sách lợi các chứng <class 'str'>
# GT: các dự án có vốn đầu tư nước ngoài. Rà soát lại chương
# PRED: các dữ án có vốn đầu tư nước ngoài. Rà sách lợi các chứng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  53%|█████▎    | 107/201 [04:22<03:52,  2.47s/it]
# DEBUG result: trình hồi nhập kín tế của TP. Về văn hoá - xã hội; đây mang xã <class 'str'>
# GT: trình hội nhập kinh tế của TP. Về văn hóa - xã hội : đẩy mạnh xã
# PRED: trình hồi nhập kín tế của TP. Về văn hoá - xã hội; đây mang xã
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  54%|█████▎    | 108/201 [04:24<03:52,  2.50s/it]
# DEBUG result: hỏi hôm 1 phút trước xác hồi học tập 1 khu tiên đau từ ngạn sách <class 'str'>
# GT: hội hóa, phát triển xã hội học tập, ưu tiên đầu tư ngân sách
# PRED: hỏi hôm 1 phút trước xác hồi học tập 1 khu tiên đau từ ngạn sách
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
#  54%|█████▍    | 109/201 [04:26<03:13,  2.11s/it]
# DEBUG result: cho giao duc - đã tạo. <class 'str'>
# GT: cho giáo dục - đào tạo.
# PRED: cho giao duc - đã tạo.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  55%|█████▍    | 110/201 [04:28<03:20,  2.20s/it]
# DEBUG result: Năng cao năng lực quản lý nhà nước trên các hình ước bên danh dịch vụ <class 'str'>
# GT: Nâng cao năng lực quản lý nhà nước trên các lĩnh vực kinh doanh dịch vụ
# PRED: Năng cao năng lực quản lý nhà nước trên các hình ước bên danh dịch vụ
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  55%|█████▌    | 111/201 [04:30<03:22,  2.25s/it]
# DEBUG result: van hoi ; khả phục những sở hữu , tên các trong quản lý và hoạt động <class 'str'>
# GT: văn hóa; khắc phục những sơ hở, tiêu cực trong quản lý và hoạt động
# PRED: van hoi ; khả phục những sở hữu , tên các trong quản lý và hoạt động
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  56%|█████▌    | 112/201 [04:33<03:25,  2.30s/it]
# DEBUG result: văn hoá. Tiếp tục tập trung người lực cho chống trừ 3 giảm … <class 'str'>
# GT: văn hóa. Tiếp tục tập trung nguồn lực cho chương trình 3 giảm...
# PRED: văn hoá. Tiếp tục tập trung người lực cho chống trừ 3 giảm …
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  56%|█████▌    | 113/201 [04:35<03:33,  2.43s/it]
# DEBUG result: Vui lòng tiếp viết mình thưa ng xưa. Đang tự biết hồi báo các sự phản ứng. <class 'str'>
# GT: Viết tiếp về vụ anh Trương Xuân Đại. Ngay từ khi tờ báo có bài " Số phận của
# PRED: Vui lòng tiếp viết mình thưa ng xưa. Đang tự biết hồi báo các sự phản ứng.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  57%|█████▋    | 114/201 [04:38<03:20,  2.31s/it]
# DEBUG result: having regard not to that 'that's him', there'd been a lot of big boys this set, <class 'str'>
# GT: những người nói lên sự thật " phát hành, nhiều bạn đọc đã bày tỏ sự chia sẻ,
# PRED: having regard not to that 'that's him', there'd been a lot of big boys this set,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  57%|█████▋    | 115/201 [04:40<03:35,  2.50s/it]
# DEBUG result: ng hồ anh Trường Xuân Đại. Mặt bàn đác 6 7 tuổi ở Q. Mắt n' gửi tông anh Trường <class 'str'>
# GT: ủng hộ anh Trương Xuân Đại. Một bạn đọc 67 tuổi ở Q.11 đến gửi tặng anh Trương
# PRED: ng hồ anh Trường Xuân Đại. Mặt bàn đác 6 7 tuổi ở Q. Mắt n' gửi tông anh Trường
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  58%|█████▊    | 116/201 [04:44<03:47,  2.67s/it]
# DEBUG result: Xuân Đủ 150.000 đồng, mà có gì vì tên Nhưng ở? Tôi Bình gửi tặng 100.000, <class 'str'>
# GT: Xuân Đại 150.000 đồng, một cô gái tên Nhung ở Tân Bình gửi tặng 100.000 đ,
# PRED: Xuân Đủ 150.000 đồng, mà có gì vì tên Nhưng ở? Tôi Bình gửi tặng 100.000,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  58%|█████▊    | 117/201 [04:46<03:37,  2.59s/it]
# DEBUG result: mẹ thành mẹ nên Hai đen quý 200.000. Sand và mẹ là Hai, <class 'str'>
# GT: một thanh niên tên Hà đến gửi 200.000 đ. Sau đó nữa là rất
# PRED: mẹ thành mẹ nên Hai đen quý 200.000. Sand và mẹ là Hai,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  59%|█████▊    | 118/201 [04:48<03:11,  2.31s/it]
# DEBUG result: which is less than the other, but the difference is very small. <class 'str'>
# GT: nhiều bạn đọc gọi đến bày tỏ sự chia sẻ, ủng hộ.
# PRED: which is less than the other, but the difference is very small.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  59%|█████▉    | 119/201 [04:50<03:11,  2.33s/it]
# DEBUG result: Bạn biết tên bà 'tuần' từ cùng người 'Trinh gia tăng nhóm công nhân' <class 'str'>
# GT: Ban biên tập báo Tuổi Trẻ cũng quyết định gửi tặng nhóm công nhân
# PRED: Bạn biết tên bà 'tuần' từ cùng người 'Trinh gia tăng nhóm công nhân'
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  60%|█████▉    | 120/201 [04:53<03:17,  2.44s/it]
# DEBUG result: để tối 100 tháng các 0 tháng làm công A5 10 tháng đóng. Đóng, đã người đóng <class 'str'>
# GT: đã tố cáo tiêu cực ở đường liên cảng A5 10 triệu đồng. Đừng để người dân
# PRED: để tối 100 tháng các 0 tháng làm công A5 10 tháng đóng. Đóng, đã người đóng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# ...
# GT: Biển có vùng nội thủy, lãnh hải, vùng đặc quyền kinh tế và thềm lục địa với
# PRED: Biên có vùng nội thụy, tành thái, vùng đặc quyền kinh tế và thêm lịch sử.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  81%|████████  | 163/201 [06:38<01:34,  2.48s/it]
# DEBUG result: Tên tôi trên 1 triệu km² (gặp 8 điện tích đặt trên): 1 triệu km² <class 'str'>
# GT: diện tích trên 1 triệu km2 (gấp 3 diện tích đất liền : 1 triệu km2 /
# PRED: Tên tôi trên 1 triệu km² (gặp 8 điện tích đặt trên): 1 triệu km²
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
#  82%|████████▏ | 164/201 [06:39<01:13,  1.98s/it]
# DEBUG result: 330.000km <class 'str'>
# GT: 330.000 km2)
# PRED: 330.000km
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  82%|████████▏ | 165/201 [06:41<01:17,  2.17s/it]
# DEBUG result: Trong đó có 2 quần đảo thăng Sa, Trường Sa và 2.577 đảo thủ, nhỏ, <class 'str'>
# GT: Trong đó có 2 quần đảo Hoàng Sa, Trường Sa và 2.577 đảo lớn, nhỏ,
# PRED: Trong đó có 2 quần đảo thăng Sa, Trường Sa và 2.577 đảo thủ, nhỏ,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  83%|████████▎ | 166/201 [06:44<01:20,  2.31s/it]
# DEBUG result: gần vì xa bỏ, hẹp thành phong tuyến bảo vệ, kiểm soát và làm chủ <class 'str'>
# GT: gần và xa bờ, hợp thành phòng tuyến bảo vệ, kiểm soát và làm chủ
# PRED: gần vì xa bỏ, hẹp thành phong tuyến bảo vệ, kiểm soát và làm chủ
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
#  83%|████████▎ | 167/201 [06:45<01:05,  1.94s/it]
# DEBUG result: Muj bien? <class 'str'>
# GT: vùng biển.
# PRED: Muj bien?
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  84%|████████▎ | 168/201 [06:48<01:10,  2.12s/it]
# DEBUG result: Cả vị thứ chiến lược quan trọng: mọi tâm Thế Bình Dương và Anh Dương, <class 'str'>
# GT: Có vị trí chiến lược quan trọng : nối liền Thái Bình Dương với Ấn Độ Dương,
# PRED: Cả vị thứ chiến lược quan trọng: mọi tâm Thế Bình Dương và Anh Dương,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  84%|████████▍ | 169/201 [06:50<01:12,  2.25s/it]
# DEBUG result: chào A với cháu An, chào Vợ với Trung Đông. Giáo viên quốc tế thưa <class 'str'>
# GT: châu Á với châu Âu, châu Úc với Trung Đông. Giao lưu quốc tế thuận
# PRED: chào A với cháu An, chào Vợ với Trung Đông. Giáo viên quốc tế thưa
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
#  85%|████████▍ | 170/201 [06:52<01:00,  1.95s/it]
# DEBUG result: !?, phát triển ngành biên. <class 'str'>
# GT: lợi, phát triển ngành biển.
# PRED: !?, phát triển ngành biên.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  85%|████████▌ | 171/201 [06:54<01:03,  2.11s/it]
# DEBUG result: Có khi hầu biên lá vùng nhiệt đội tạo điều kiện cho sâu vât biên phát <class 'str'>
# GT: Có khí hậu biển là vùng nhiệt đới tạo điều kiện cho sinh vật biển phát
# PRED: Có khi hầu biên lá vùng nhiệt đội tạo điều kiện cho sâu vât biên phát
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
#  86%|████████▌ | 172/201 [06:55<00:52,  1.81s/it]
# DEBUG result: trên, tôi tôi tôi. <class 'str'>
# GT: triển, tồn tại tốt.
# PRED: trên, tôi tôi tôi.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  86%|████████▌ | 173/201 [06:57<00:54,  1.95s/it]
# DEBUG result: Có tài nguyên sinh vật và khoáng sản phong phú, ta dâng, quý hôm. <class 'str'>
# GT: Có tài nguyên sinh vật và khoáng sản phong phú, đa dạng, quý hiếm.
# PRED: Có tài nguyên sinh vật và khoáng sản phong phú, ta dâng, quý hôm.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  87%|████████▋ | 174/201 [07:00<01:02,  2.30s/it]
# DEBUG result: Vùng bình và hải đảo mất xa có vị trí chốn lốt hết sức tơ lớn, có ảnh hưởng <class 'str'>
# GT: Vùng biển và hải đảo nước ta có vị trí chiến lược hết sức to lớn, có ảnh hưởng
# PRED: Vùng bình và hải đảo mất xa có vị trí chốn lốt hết sức tơ lớn, có ảnh hưởng
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  87%|████████▋ | 175/201 [07:03<01:04,  2.50s/it]
# DEBUG result: trúc tập đến, sự nghiệp bảo vệ nên đều lập danh tọa và xây dựng chủ nghĩa. <class 'str'>
# GT: trực tiếp đến sự nghiệp bảo vệ nền độc lập dân tộc và xây dựng chủ nghĩa
# PRED: trúc tập đến, sự nghiệp bảo vệ nên đều lập danh tọa và xây dựng chủ nghĩa.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  88%|████████▊ | 176/201 [07:06<01:02,  2.49s/it]
# DEBUG result: xã hội, có hiện quan thực tập đến sự phản vinh của đất nước, đến văn <class 'str'>
# GT: xã hội, có liên quan trực tiếp đến sự phồn vinh của đất nước, đến văn
# PRED: xã hội, có hiện quan thực tập đến sự phản vinh của đất nước, đến văn
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
#  88%|████████▊ | 177/201 [07:07<00:52,  2.18s/it]
# DEBUG result: mình và hành phó của mình đâu. <class 'str'>
# GT: minh và hạnh phúc của nhân dân.
# PRED: mình và hành phó của mình đâu.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
#  89%|████████▊ | 178/201 [07:08<00:42,  1.85s/it]
# DEBUG result: Bạn chết của thành công <class 'str'>
# GT: BẢN CHẤT CỦA THÀNH CÔNG
# PRED: Bạn chết của thành công
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  89%|████████▉ | 179/201 [07:11<00:45,  2.05s/it]
# DEBUG result: 既然bao gai ban ti, hoi thanh cing la gi ma bao ke bo ca cua di min theo dai? Phoi chang <class 'str'>
# GT: Đã bao giờ bạn tự hỏi thành công là gì mà bao kẻ bỏ cả cuộc đời mình theo đuổi? Phải chăng
# PRED: 既然bao gai ban ti, hoi thanh cing la gi ma bao ke bo ca cua di min theo dai? Phoi chang
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  90%|████████▉ | 180/201 [07:14<00:47,  2.28s/it]
# DEBUG result: This isn't what I mean, but I'm not going back. So? I don't want to be a tourist. I don't want to be a tourist, no. <class 'str'>
# GT: đó là kết quả hoàn hảo trong công việc, sự chính xác đến từng chi tiết? Hay đó là cách nói
# PRED: This isn't what I mean, but I'm not going back. So? I don't want to be a tourist. I don't want to be a tourist, no.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  90%|█████████ | 181/201 [07:17<00:50,  2.51s/it]
# DEBUG result: khác của từ thành đạt, nghĩa là có điều cũng sợi gưu sang, điều mới nghĩa là phục ợ <class 'str'>
# GT: khác của từ thành đạt, nghĩa là có được một cuộc sống giàu sang, được mọi người nể phục?
# PRED: khác của từ thành đạt, nghĩa là có điều cũng sợi gưu sang, điều mới nghĩa là phục ợ
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  91%|█████████ | 182/201 [07:19<00:46,  2.43s/it]
# DEBUG result: Vậy thế bạn hãy dành chút thời gian để kể những suy ngẫm. <class 'str'>
# GT: Vậy thì bạn hãy dành chút thời gian để lặng mình suy ngẫm.
# PRED: Vậy thế bạn hãy dành chút thời gian để kể những suy ngẫm.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  91%|█████████ | 183/201 [07:21<00:43,  2.41s/it]
# DEBUG result: Vâng rằng sẽ chủ cho bạn có những người thân, trách thành công theo một cách giản dị tính khi <class 'str'>
# GT: Cuộc sống sẽ chỉ cho bạn có những người thành đạt được thành công theo một cách giản dị đến bất
# PRED: Vâng rằng sẽ chủ cho bạn có những người thân, trách thành công theo một cách giản dị tính khi
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  92%|█████████▏| 184/201 [07:23<00:34,  2.02s/it]
# DEBUG result: لغة <class 'str'>
# GT: ngờ
# PRED: لغة
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  92%|█████████▏| 185/201 [07:26<00:37,  2.33s/it]
# DEBUG result: Thanh cũng là khi bố vẫn còn trai có dùng khi biết sao bap, nếu những món ăn mẹ thích nhau <class 'str'>
# GT: Thành công là khi bố và con trai có dũng khí bước vào bếp, nấu những món ăn mẹ thích nhân
# PRED: Thanh cũng là khi bố vẫn còn trai có dùng khi biết sao bap, nếu những món ăn mẹ thích nhau
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  93%|█████████▎| 186/201 [07:29<00:39,  2.66s/it]
# DEBUG result: ngay 8-3. Mời cạnh cơ thế hai màn, mời cố sát đang lệ phạt có mâu đạo sản thi lợi ngã sang <class 'str'>
# GT: ngày 8 - 3. Món canh có thể hơi mặn, món cá sốt đáng lẽ phải có màu đỏ sậm thì lại ngả sang
# PRED: ngay 8-3. Mời cạnh cơ thế hai màn, mời cố sát đang lệ phạt có mâu đạo sản thi lợi ngã sang
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  93%|█████████▎| 187/201 [07:32<00:38,  2.75s/it]
# DEBUG result: mai ... đen chảy. Những nhìn màn còn, mẹ vẫn còn cười. Ôi vì hai bố con không thể thành <class 'str'>
# GT: màu... đen cháy. Nhưng nhìn mâm cơm, mẹ vẫn cười. Bởi vì hai bố con không thể thành
# PRED: mai ... đen chảy. Những nhìn màn còn, mẹ vẫn còn cười. Ôi vì hai bố con không thể thành
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  94%|█████████▎| 188/201 [07:35<00:35,  2.75s/it]
# DEBUG result: sing three "chicken tring" beep nice, phung lai thanh cong khi tay me "da ting" cua tinh yeu. <class 'str'>
# GT: công trên " chiến trường " bếp núc, nhưng lại thành công khi tặng mẹ " đoá hồng " của tình yêu.
# PRED: sing three "chicken tring" beep nice, phung lai thanh cong khi tay me "da ting" cua tinh yeu.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  94%|█████████▍| 189/201 [07:38<00:34,  2.84s/it]
# DEBUG result: một mùi quả ở nghĩa hơn cả những mùi quả quý giá, hành phúc ấy lạnh lẽn trong nét. <class 'str'>
# GT: Một món quà ý nghĩa hơn cả những món quà quý giá, hạnh phúc ấy long lanh in trong mắt
# PRED: một mùi quả ở nghĩa hơn cả những mùi quả quý giá, hành phúc ấy lạnh lẽn trong nét.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
#  95%|█████████▍| 190/201 [07:39<00:25,  2.29s/it]
# DEBUG result: mè. <class 'str'>
# GT: mẹ.
# PRED: mè.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  95%|█████████▌| 191/201 [07:42<00:24,  2.45s/it]
# DEBUG result: Thank ing còn là hữu ảnh mắt câu bé bị dù tật ở chân, không bao giờ đi lại bình thường <class 'str'>
# GT: Thành công còn là hình ảnh một cậu bé bị dị tật ở chân, không bao giờ đi lại bình thường
# PRED: Thank ing còn là hữu ảnh mắt câu bé bị dù tật ở chân, không bao giờ đi lại bình thường
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  96%|█████████▌| 192/201 [07:45<00:23,  2.64s/it]
# DEBUG result: 1. Tôi thử câu này để mua lẻ có thể thưởng câu thứ bóng đá. Sau báo nỗ lực khẳng câu. <class 'str'>
# GT: được. Từ nhỏ cậu đã nuôi ước mơ trở thành cầu thủ bóng đá. Sau bao nỗ lực khổ luyện, cậu
# PRED: 1. Tôi thử câu này để mua lẻ có thể thưởng câu thứ bóng đá. Sau báo nỗ lực khẳng câu.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  96%|█████████▌| 193/201 [07:48<00:21,  2.74s/it]
# DEBUG result: là từ thứ nhất của thứ 2 là từ trong một đời, trong nhờ, nó chứa bao giờ tất cả chính thức ra sao. <class 'str'>
# GT: bé trở thành cầu thủ dự bị trong một đội bóng nhỏ, và chưa bao giờ được chính thức ra sân.
# PRED: là từ thứ nhất của thứ 2 là từ trong một đời, trong nhờ, nó chứa bao giờ tất cả chính thức ra sao.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  97%|█████████▋| 194/201 [07:50<00:19,  2.72s/it]
# DEBUG result: Những đời không phải là thách bại. Trái lại, thành công đời này khi còn bạn nhỏ, với bảo <class 'str'>
# GT: Nhưng đó không phải là thất bại. Trái lại, thành công đã nở hoa khi cậu bé năm xưa, với bao
# PRED: Những đời không phải là thách bại. Trái lại, thành công đời này khi còn bạn nhỏ, với bảo
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  97%|█████████▋| 195/201 [07:52<00:14,  2.48s/it]
# DEBUG result: ugh, like we used to, the whole thing been such the other side of the coin. <class 'str'>
# GT: nghị lực và quyết tâm, đã chiến thắng hoàn cảnh để theo đuổi ước mơ từ ngày thơ bé.
# PRED: ugh, like we used to, the whole thing been such the other side of the coin.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
#  98%|█████████▊| 196/201 [07:54<00:11,  2.28s/it]
# DEBUG result: Thanh công ấy, loài cỏ mây người đạt được ? <class 'str'>
# GT: Thành công ấy, liệu có mấy người đạt được?
# PRED: Thanh công ấy, loài cỏ mây người đạt được ?
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  98%|█████████▊| 197/201 [07:58<00:10,  2.62s/it]
# DEBUG result: Sau mỗi mùa thịt đã lên, có bao "sữa" buôn rau khi bệnh mình trở thành "sữa". Hai bảy đơn, <class 'str'>
# GT: Sau mỗi mùa thi đại học, có bao " sĩ tử " buồn rầu khi biết mình trở thành " sĩ tử ". Hai bảy điểm,
# PRED: Sau mỗi mùa thịt đã lên, có bao "sữa" buôn rau khi bệnh mình trở thành "sữa". Hai bảy đơn,
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  99%|█████████▊| 198/201 [08:00<00:07,  2.55s/it]
# DEBUG result: You think stay. Nothing can make you like NO.2 lay off? Hai baby phay man! To that a king pha? <class 'str'>
# GT: cao thật đấy. Nhưng cao mà làm gì khi NV1 lấy tới hai bảy phẩy năm? Đó thật ra không phải
# PRED: You think stay. Nothing can make you like NO.2 lay off? Hai baby phay man! To that a king pha?
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#  99%|█████████▉| 199/201 [08:03<00:05,  2.71s/it]
# DEBUG result: là thứ hai, chứ là khi thành công - bị - trừ - hơn mà thì. Quả sống vẫn chạy đều hơi vội. <class 'str'>
# GT: là thất bại, chỉ là khi thành công - bị - trì - hoãn mà thôi. Cuộc sống vẫn chào đón họ với
# PRED: là thứ hai, chứ là khi thành công - bị - trừ - hơn mà thì. Quả sống vẫn chạy đều hơi vội.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# 100%|█████████▉| 200/201 [08:06<00:02,  2.94s/it]
# DEBUG result: Nv2, Nv3. Quan trong lĩnh lĩnh nói lúc hát sức dễ khủng tình mình. Tôi lấy nghĩa văn nguyên. <class 'str'>
# GT: NV2, NV3. Quan trọng là họ đã nỗ lực hết sức để khẳng định mình. Đó là ý nghĩa vẹn nguyên
# PRED: Nv2, Nv3. Quan trong lĩnh lĩnh nói lúc hát sức dễ khủng tình mình. Tôi lấy nghĩa văn nguyên.
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# 100%|██████████| 201/201 [08:08<00:00,  2.43s/it]
# DEBUG result: của các ký thú, và cũng là bản chất của thành công. <class 'str'>
# GT: của các kỳ thi, và cũng là bản chất của thành công.
# PRED: của các ký thú, và cũng là bản chất của thành công.

# %%
for i, r in enumerate(results[:5]):
    print(f"Sample {i}")
    print("GT   :", repr(r["gt"]))
    print("PRED :", repr(r["pred"]))
    print("-" * 50)
# Out:
# Sample 0
# GT   : 'Thứ trưởng Bộ Tài nguyên & môi trường Đặng Hùng Võ tâm đắc với'
# PRED : 'Thử thường, Bộ tài nguyên và môi trường Đảng Hùng Võ đãn đạo về:'
# --------------------------------------------------
# Sample 1
# GT   : 'cơ chế " khuyến khích nhà đầu tư thỏa thuận với người sử dụng đất để nhận'
# PRED : 'có thể "khuyến khích mua sắm từ thỏa thuận với những sản phẩm đặc thù nhân'
# --------------------------------------------------
# Sample 2
# GT   : 'chuyển nhượng hoặc thuê quyền sử dụng đất, nhận góp vốn bằng quyền sử'
# PRED : 'chuyển những hoặc thực quyết sử dụng đất, nhân góp vốn bảng quyết sử'
# --------------------------------------------------
# Sample 3
# GT   : 'dụng đất... " Nhưng tại hội nghị hôm qua, tiếng nói từ các sở tài nguyên'
# PRED : 'dùng đặt ... " Nhưng tại hôm ngày hôm qua, tiếng nói: hứ cái gì đó từ ngày'
# --------------------------------------------------
# Sample 4
# GT   : '& môi trường lại đều đồng thanh " loại bỏ " điều khoản này ra khỏi dự thảo.'
# PRED : 'và mới truyền lên thêm hành "boo" ở tiên chuẩn này ra lệch dù tháo.'
# --------------------------------------------------

# %% [markdown]
# CER

# %%
from jiwer import cer

total_cer = 0.0
count = 0

for r in results:
    gt = r["gt"].strip()
    pred = r["pred"].strip()

    if len(gt) == 0:
        continue

    total_cer += cer(gt, pred)
    count += 1

avg_cer = total_cer / count
print(f"Average CER on test set: {avg_cer:.4f}")
# Out:
# Average CER on test set: 0.3257

# %% [markdown]
# WER

# %%
from jiwer import wer

total_wer = 0.0
count = 0

for r in results:
    gt = r["gt"].strip()
    pred = r["pred"].strip()

    if len(gt) == 0:
        continue

    total_wer += wer(gt, pred)
    count += 1

print(f"Average WER: {total_wer / count:.4f}")
# Out:
# Average WER: 0.6543
